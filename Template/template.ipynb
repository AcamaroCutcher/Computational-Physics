# %% [markdown]
# # Template - Make copy when starting jupyter Notebook

# %% [markdown]
# For some reason just making a .ipynb does not include the json stuff. So it will not render in github. So use this until you figure out a way to use it.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Hello
